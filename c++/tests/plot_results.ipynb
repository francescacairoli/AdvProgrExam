# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f_int = open('benchmark_different_int_1.txt','r')
f_double = open('benchmark_different_double_1.txt','r')

# %%
number_lookups = []
int_global_time = []
int_time_per_oper = []

for i, line in enumerate(f_int):
    if i > 2:
        n, glob, op, l = line.split()
        number_lookups.append(int(n))
        int_global_time.append(float(glob))
        int_time_per_oper.append(float(op))

# %%
double_global_time = []
double_time_per_oper = []

for i, line in enumerate(f_double):
    if i > 2:
        n, glob, op, l = line.split()
        double_global_time.append(float(glob))
        double_time_per_oper.append(float(op))

# %%
plt.semilogy(number_lookups, int_time_per_oper, label="int")
plt.semilogy(number_lookups, double_time_per_oper, label="double")
plt.xlabel("N")
plt.legend()
plt.show()

# %%
double_time_per_oper
# Out:
# [0.26,
#  0.26,
#  0.26,
#  0.26,
#  0.26,
#  0.266667,
#  0.268571,
#  0.2725,
#  0.277778,
#  0.282,
#  0.287273,
#  0.29,
#  0.3,
#  0.297143,
#  0.304,
#  0.3025,
#  0.304706,
#  0.307778,
#  0.310526,
#  0.312,
#  0.314286,
#  0.316364,
#  0.318261,
#  0.38,
#  0.36,
#  0.367692,
#  0.388889,
#  0.425714,
#  0.342069,
#  0.342667,
#  0.343871,
#  0.345,
#  0.352121,
#  0.348235,
#  0.348,
#  0.349444,
#  0.35027,
#  0.36,
#  0.354872,
#  0.3555,
#  0.35561,
#  0.35619,
#  0.357674,
#  0.358182,
#  0.363556,
#  0.424348,
#  0.402553,
#  0.396667,
#  0.4,
#  0.3972,
#  0.398431,
#  0.399231,
#  0.401887,
#  0.401481,
#  0.402909,
#  0.405714,
#  0.405614,
#  0.405862,
#  0.40678,
#  0.409333,
#  0.410164,
#  0.409677,
#  0.411746,
#  0.410625,
#  0.411692,
#  0.413939,
#  0.421194,
#  0.422059,
#  0.42058,
#  0.377714,
#  0.38,
#  0.3875,
#  0.410959,
#  0.405946,
#  0.3776,
#  0.377895,
#  0.386494,
#  0.379744,
#  0.380253,
#  0.39275,
#  0.381975,
#  0.388293,
#  0.383133,
#  0.383571,
#  0.391059,
#  0.385116,
#  0.386437,
#  0.386364,
#  0.38764,
#  0.387111,
#  0.387692,
#  0.38913,
#  0.389462,
#  0.390426,
#  0.390105,
#  0.391458,
#  0.39134,
#  0.392857,
#  0.392525,
#  0.434,
#  0.414455,
#  0.404706,
#  0.404854,
#  0.401154,
#  0.399619,
#  0.403396,
#  0.400374,
#  0.401111,
#  0.400734,
#  0.401818,
#  0.398559,
#  0.399643,
#  0.400177,
#  0.399474,
#  0.400174,
#  0.4,
#  0.406496,
#  0.401525,
#  0.401176,
#  0.402667,
#  0.404463,
#  0.460164,
#  0.453171,
#  0.451613,
#  0.5344,
#  0.450794,
#  0.451181,
#  0.452813,
#  0.462636,
#  0.450923,
#  0.450534,
#  0.450758,
#  0.449925,
#  0.451194,
#  0.452444,
#  0.456029,
#  0.452117,
#  0.453768,
#  0.454245,
#  0.454857,
#  0.454894,
#  0.455211,
#  0.455524,
#  0.455972,
#  0.456414,
#  0.456575,
#  0.457007,
#  0.456757,
#  0.457852,
#  0.458133,
#  0.458411,
#  0.459211,
#  0.459477,
#  0.461169,
#  0.459226,
#  0.46,
#  0.501529,
#  0.462025,
#  0.461635,
#  0.46175,
#  0.46236,
#  0.462346,
#  0.462822,
#  0.463293,
#  0.463879,
#  0.464217,
#  0.464431,
#  0.465,
#  0.465444,
#  0.465765,
#  0.466082,
#  0.466047,
#  0.46659,
#  0.467241,
#  0.467429,
#  0.467841,
#  0.468588,
#  0.468315,
#  0.469944,
#  0.470889,
#  0.469613,
#  0.469451,
#  0.470164,
#  0.470217,
#  0.470486,
#  0.471613,
#  0.471337,
#  0.471277,
#  0.471746,
#  0.471684,
#  0.472356,
#  0.4725,
#  0.47285,
#  0.474536,
#  0.473333,
#  0.473163,
#  0.473909,
#  0.474141,
#  0.474472]
